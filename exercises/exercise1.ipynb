# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
earthquake = pd.read_csv('https://raw.githubusercontent.com/mosesyhc/de300-2026wi/refs/heads/main/datasets/Canadian-Earthquakes-2010-2019.csv')

# %%
# take a glimpse of the data
earthquake.head()
# Out:
#   magnitude_codelist  magnitude magnitude_type                      date  \
# 0                 <2        1.7             ML  2010-01-01T00:16:49+0000
# 1                  2        2.2             MN  2010-01-01T00:52:50+0000
# 2                 <2        1.8             MN  2010-01-01T03:21:58+0000
# 3                 <2        1.5             MN  2010-01-01T04:14:51+0000
# 4                 <2        1.6             ML  2010-01-01T04:15:17+0000
#
#                         place  depth   latitude   longitude  OBJECTID  \
# 0        81 km NE  of Seattle    0.0  48.192001 -121.677002         1
# 1      86 km NW from Maniwaki   18.0  47.028999  -76.583000         2
# 2  21 km NW from Mont-Laurier   18.0  46.651001  -75.734001         3
# 3     CHARLEVOIX SEISMIC ZONE   13.0  47.740002  -69.741997         4
# 4        83 km W   of Gold R.   11.6  49.500999 -127.222000         5
#
#    longitude_geom  latitude_geom
# 0     -121.677315      48.191706
# 1      -76.583303      47.028909
# 2      -75.733902      46.650809
# 3      -69.742000      47.740210
# 4     -127.222216      49.500705

# %%
# view a summary of the full data
earthquake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44561 entries, 0 to 44560
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   magnitude_codelist  44561 non-null  object
#  1   magnitude           44561 non-null  float64
#  2   magnitude_type      44462 non-null  object
#  3   date                44561 non-null  object
#  4   place               44561 non-null  object
#  5   depth               44561 non-null  float64
#  6   latitude            44561 non-null  float64
#  7   longitude           44561 non-null  float64
#  8   OBJECTID            44561 non-null  int64
#  9   longitude_geom      44561 non-null  float64
#  10  latitude_geom       44561 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 3.7+ MB

# %%
# checks for duplicates (also ask if duplicates make sense)
earthquake[earthquake.duplicated()]

#iloc:
# Out:
# Empty DataFrame
# Columns: [magnitude_codelist, magnitude, magnitude_type, date, place, depth, latitude, longitude, OBJECTID, longitude_geom, latitude_geom]
# Index: []

# %%
# a quick numerical summary
earthquake.describe(include = 'all')
# Out:
#        magnitude_codelist     magnitude magnitude_type  \
# count               44561  44561.000000          44462
# unique                  6           NaN              7
# top                    <2           NaN             ML
# freq                19764           NaN          29509
# mean                  NaN      2.134070            NaN
# std                   NaN      0.828096            NaN
# min                   NaN     -1.400000            NaN
# 25%                   NaN      1.600000            NaN
# 50%                   NaN      2.100000            NaN
# 75%                   NaN      2.700000            NaN
# max                   NaN      7.700000            NaN
#
#                             date                    place         depth  \
# count                      44561                    44561  44561.000000
# unique                     44481                    18639           NaN
# top     2018-07-02T04:08:13+0000  CHARLEVOIX SEISMIC ZONE           NaN
# freq                           3                     1250           NaN
# mean                         NaN                      NaN     12.852194
# std                          NaN                      NaN      9.963145
# min                          NaN                      NaN     -0.500000
# 25%                          NaN                      NaN      5.000000
# 50%                          NaN                      NaN     10.000000
# 75%                          NaN                      NaN     18.000000
# max                          NaN                      NaN    214.000000
#
#             latitude     longitude      OBJECTID  longitude_geom  \
# count   44561.000000  44561.000000  44561.000000    44561.000000
# unique           NaN           NaN           NaN             NaN
# top              NaN           NaN           NaN             NaN
# freq             NaN           NaN           NaN             NaN
# mean       53.351863   -118.953322  22281.000000     -118.953299
# std         6.214464     23.696484  12863.797009       23.696493
# min        40.808998   -148.811005      1.000000     -148.810526
# 25%        49.169998   -132.427994  11141.000000     -132.427618
# 50%        52.137001   -129.671997  22281.000000     -129.672016
# 75%        56.514999   -121.947998  33421.000000     -121.948318
# max        82.608002    -39.320000  44561.000000      -39.319968
#
#         latitude_geom
# count    44561.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean        53.351830
# std          6.214465
# min         40.808509
# 25%         49.170009
# 50%         52.136507
# 75%         56.515206
# max         82.607812

# %%
# checks for possible statistical assumption(s)
import scipy.stats as sps
sps.normaltest(earthquake['magnitude'])
# Out:
# NormaltestResult(statistic=np.float64(1597.6658124732553), pvalue=np.float64(0.0))

# %%
# extract only numeric variables
earthquake.select_dtypes('number')
# Out:
#        magnitude  depth   latitude   longitude  OBJECTID  longitude_geom  \
# 0            1.7    0.0  48.192001 -121.677002         1     -121.677315
# 1            2.2   18.0  47.028999  -76.583000         2      -76.583303
# 2            1.8   18.0  46.651001  -75.734001         3      -75.733902
# 3            1.5   13.0  47.740002  -69.741997         4      -69.742000
# 4            1.6   11.6  49.500999 -127.222000         5     -127.222216
# ...          ...    ...        ...         ...       ...             ...
# 44556        1.8   14.0  50.487999 -121.035004     44557     -121.035415
# 44557        2.4    0.0  48.250000  -78.448997     44558      -78.449004
# 44558        2.0   10.5  50.526001 -121.005997     44559     -121.006115
# 44559        1.9   18.0  45.083000  -74.718002     44560      -74.718302
# 44560        1.3    3.8  47.492001  -70.412003     44561      -70.412401
#
#        latitude_geom
# 0          48.191706
# 1          47.028909
# 2          46.650809
# 3          47.740210
# 4          49.500705
# ...              ...
# 44556      50.487806
# 44557      48.250409
# 44558      50.526206
# 44559      45.083409
# 44560      47.491910
#
# [44561 rows x 7 columns]

# %%
# for example, normality test
sps.shapiro(earthquake['magnitude'])
# Out:
# /usr/local/lib/python3.12/dist-packages/scipy/stats/_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 44561.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=np.float64(0.9877396508026011), pvalue=np.float64(1.179774985585813e-49))

# %%
# pairwise correlation
earthquake_num = earthquake.select_dtypes('number')
##np.corrcoef(earthquake_num)
earthquake_num.corr()
# Out:
#                 magnitude     depth  latitude  longitude  OBJECTID  \
# magnitude        1.000000 -0.127958  0.196699  -0.110731 -0.006523
# depth           -0.127958  1.000000 -0.107744  -0.005796 -0.103983
# latitude         0.196699 -0.107744  1.000000  -0.266265 -0.000391
# longitude       -0.110731 -0.005796 -0.266265   1.000000  0.049094
# OBJECTID        -0.006523 -0.103983 -0.000391   0.049094  1.000000
# longitude_geom  -0.110731 -0.005796 -0.266265   1.000000  0.049093
# latitude_geom    0.196699 -0.107744  1.000000  -0.266265 -0.000390
#
#                 longitude_geom  latitude_geom
# magnitude            -0.110731       0.196699
# depth                -0.005796      -0.107744
# latitude             -0.266265       1.000000
# longitude             1.000000      -0.266265
# OBJECTID              0.049093      -0.000390
# longitude_geom        1.000000      -0.266265
# latitude_geom        -0.266265       1.000000

# %%
sns.set(context='talk', style='ticks')  # simply for aesthetics
sns.set_palette('magma')
# %matplotlib inline

#earthquake = earthquake.sample(n=500)  # (if too slow) for illustration purposes

# %%
# histogram for continuous variables using pandas built-in plots
earthquake.plot.hist(column = 'depth')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# relative frequency? ...
sns.histplot(x = 'depth', data = earthquake, stat = 'probability')
# Out:
# <Axes: xlabel='depth', ylabel='Probability'>

# %%
earthquake.info()
g = sns.FacetGrid(earthquake, col = 'magnitude_type', sharex = False)
g.map(sns.violinplot, 'depth')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44561 entries, 0 to 44560
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   magnitude_codelist  44561 non-null  object
#  1   magnitude           44561 non-null  float64
#  2   magnitude_type      44462 non-null  object
#  3   date                44561 non-null  object
#  4   place               44561 non-null  object
#  5   depth               44561 non-null  float64
#  6   latitude            44561 non-null  float64
#  7   longitude           44561 non-null  float64
#  8   OBJECTID            44561 non-null  int64
#  9   longitude_geom      44561 non-null  float64
#  10  latitude_geom       44561 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 3.7+ MB
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# counts for categorical variables
sns.countplot()
sns.barplot()

# %%
sns.jointplot(x = 'depth', y = 'magnitude', data = earthquake)

# %%
#pairwise plots  (time-consuming)
sns.pairplot(earthquake.sample(500))

# %%
sns.histplot(data=earthquake, x='magnitude', bins = 30, color='orange')
plt.xticks([0, 2, 4, 6, 8])
plt.show()
